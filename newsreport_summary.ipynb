# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalyanianikkath/NM-Genrative-AI/blob/main/newsreport_summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ Step 1: Install necessary packages
# !pip install -q newspaper3k transformers

# ✅ Step 2: Import libraries
from newspaper import Article
from transformers import BartTokenizer, BartForConditionalGeneration
import torch

# ✅ Step 3: Load BART model for summarization
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')

# ✅ Step 4: Function to extract article and summarize
def summarize_article(url):
    # Extract article using newspaper3k
    article = Article(url)
    article.download()
    article.parse()
    text = article.text

    print("📰 Full Article Extracted:\n")
    print(text[:1000] + '...\n')  # Show first 1000 characters

    # Tokenize and summarize
    inputs = tokenizer.encode(text, return_tensors='pt', max_length=1024, truncation=True)
    summary_ids = model.generate(inputs, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    print("🧠 Summary:\n")
    print(summary)

# ✅ Step 5: Input a news article URL
url = input("🔗 Enter the news article URL: ")
summarize_article(url)
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 31.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 5.7 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-64efd943d1d9> in <cell line: 0>()
#       3
#       4 # ✅ Step 2: Import libraries
# ----> 5 from newspaper import Article
#       6 from transformers import BartTokenizer, BartForConditionalGeneration
#       7 import torch
#
# /usr/local/lib/python3.11/dist-packages/newspaper/__init__.py in <module>
# ...

# %%
# ✅ Step 1: Install required packages (fixes lxml issue too)
# !pip install -q newspaper3k transformers lxml_html_clean

# ✅ Step 2: Import libraries
from newspaper import Article
from transformers import BartTokenizer, BartForConditionalGeneration
import torch

# ✅ Step 3: Load BART model for summarization
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')

# ✅ Step 4: Function to extract article and summarize
def summarize_article(url):
    try:
        # Extract article content
        article = Article(url)
        article.download()
        article.parse()
        text = article.text

        print("📰 Full Article Extracted:\n")
        print(text[:1000] + '...\n')  # Print first part

        # Summarize using BART
        inputs = tokenizer.encode(text, return_tensors='pt', max_length=1024, truncation=True)
        summary_ids = model.generate(inputs, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
        summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        print("\n🧠 Summary:\n")
        print(summary)

    except Exception as e:
        print(f"❌ Error: {e}")

# ✅ Step 5: Paste your article URL here
url = input("🔗 Enter the news article URL: ")
summarize_article(url)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# ...
